# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from brian2 import *

# Descrição dos parâmetros do modelo
Cm = 0.1*nfarad # capacitância da membrana
Rm = 100*Mohm # resistência da membrana
El = -70*mV # potencial de equilíbrio da membrana
Vl = -50*mV # valor limiar de tensão de emissão de disparo
vr = -65*mV # valor de tensão de repouso após 'resetagem'
Ek = -80*mV # potencial de equilíbrio da membrana
tau_Gx = 0.2*ms
duration = 2*second
delta_Gx = 2*usiemens
vl_0 = -50*mV
tau_vl = 1*ms
vl_reset = 200*mV

start_scope()
G = NeuronGroup(11, model = '''
dv/dt = ((El - v) / (Cm*Rm)) + (Ix/Cm) : volt
Ix : amp
''', threshold='v>Vl', reset= 'v=vr', method='euler', dt= 0.1*ms)

#no refractancy
statemon_G = StateMonitor(G, 'v', record=0) # monitor de potencial
spikemon_G = SpikeMonitor(G) # monitor de spikes
G.Ix = [100,150,200,250,300,350,400,450,500,550,600]*pA

#forced voltage clamp
K = NeuronGroup(11, model = '''
dv/dt = ((El - v) / (Cm*Rm)) + (Ix/Cm) : volt (unless refractory)
Ix : amp
''', threshold='v>Vl', reset= 'v=vr', method='euler', dt= 0.1*ms, refractory = 'timestep(t-lastspike, dt) <= timestep(2.5*ms, dt)')

statemon_K = StateMonitor(K, 'v', record=0) # monitor de potencial
spikemon_K = SpikeMonitor(K) # monitor de spikes
K.Ix = [100,150,200,250,300,350,400,450,500,550,600]*pA

#threshold increase
L = NeuronGroup(11, model='''dv/dt = ((El - v) / (Cm*Rm)) + (Ix/Cm) : volt
dvl/dt = (vl_0 - vl) / tau_vl : volt
Ix : amp''', threshold='v>vl', reset= "v=vr;vl=vl_reset", method='euler', dt= 0.1*ms)

statemon_L = StateMonitor(L, ["v","vl"], record=True) # monitor de potencial
spikemon_L = SpikeMonitor(L) # monitor de spikes
L.Ix = [100,150,200,250,300,350,400,450,500,550,600]*pA
L.vl = vl_0

#refractory conductance with threshold increase
M = NeuronGroup(11, model='''
dv/dt = ((El - v) / (Cm*Rm)) + ((Gx*(Ek - v)) / (Cm)) + (Ix/Cm) : volt 
dvl/dt = (vl_0 - vl) / tau_vl : volt
dGx/dt = -Gx/ tau_Gx : siemens
Ix :  amp''', threshold="v>vl", reset= "v=vr;vl=vl_reset; Gx=Gx+delta_Gx", method='euler', dt= 0.1*ms)

statemon_M = StateMonitor(M, ["v","Gx","vl"], record=True) # monitor de potencial
spikemon_M = SpikeMonitor(M) # monitor de spikes
M.Ix = [100,150,200,250,300,350,400,450,500,550,600]*pA
M.Gx = 0*usiemens
M.v = El
M.vl = -50*mV

# tempo de simulação
run(duration)
mean_values_G = [mean(G.v[idx])
               for idx in range(len(G))]
mean_values_K = [mean(K.v[idx]) 
               for idx in range(len(K))]
mean_values_L = [mean(L.v[idx])
               for idx in range(len(L))]
mean_values_M = [mean(M.v[idx])
               for idx in range(len(M))]

plot(spikemon_G.count/duration , mean_values_G/mV, '--',label = "No refractancy")
plot(spikemon_K.count/duration , mean_values_K/mV, label = "Forced Voltage Clamp")
plot(spikemon_L.count/duration , mean_values_L/mV, label = "Threshold Increase")
plot(spikemon_M.count/duration , mean_values_M/mV, label = "Refractory Conductance with Threshold Increase")
xlabel('Firing rate (sp/s)')
ylabel('Mean membrane potential (mV)')
legend()
show()
# Out:
# Missing compiler_cxx fix for MSVCCompiler
