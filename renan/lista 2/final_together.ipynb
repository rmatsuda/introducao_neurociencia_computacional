# %%
# %matplotlib inline
import brian2 as b2
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Parameters
v_rest= -70*b2.mV #EL
v_reset= -65*b2.mV #Vreset
membrane_resistance = 100 * b2.Mohm #RM
membrane_capacitance = 0.1*b2.nF #CM
firing_threshold = -50 * b2.mV #VL
refractory_time = 2.5*b2.ms

refractory_time_0 =  2.5*b2.ms
tau_refractory =  1.0*b2.ms
Vth_reset =  200*b2.mV

tau_refractory =  1.0*b2.ms
Vth_reset =  200*b2.mV

E_k = -80*b2.mV
tau_Gref = 0.2*b2.ms
deltaG = 2*b2.usiemens
Gref_0 = 0*b2.siemens

simulation_time = 2
dt =  0.01 * b2.ms 

#current = [100., 200, 200.01, 250, 300, 350, 400, 450, 500, 600]
current = np.arange(100, 600, 50)

# Method without refractory
eqs = """
dv/dt =
( ( (v_rest-v)/(membrane_capacitance * membrane_resistance) ) + (current/membrane_capacitance) ) : volt
current : amp
"""
# LIF neuron using Brian2 library
neuron = b2.NeuronGroup(
    len(current), model=eqs, reset="v=v_reset", threshold="v>firing_threshold",
    refractory=False, method="euler")
neuron.v = v_rest  # set initial value
neuron.current = current*b2.pA

# monitoring membrane potential of neuron and injecting current
state_monitor = b2.StateMonitor(neuron, ["v"], record=True)
spike_monitor = b2.SpikeMonitor(neuron)
# run the simulation
b2.run(simulation_time*b2.second)

plt.figure(1)
plt.plot(neuron.current /b2.pA, spike_monitor.count/simulation_time,'--', label = 'no_refractory')

plt.figure(2)
plt.plot(neuron.current/b2.pA, neuron.v/b2.mV, '--', label = 'no_refractory')

plt.figure(3)
plt.plot(spike_monitor.count/simulation_time, neuron.v/b2.mV,'--', label = 'no_refractory')

# Method fixed voltage
eqs = """
dv/dt =
( ( (v_rest-v)/(membrane_capacitance * membrane_resistance) ) + (current/membrane_capacitance) ) : volt (unless refractory)
current : amp
"""
# LIF neuron using Brian2 library
neuron = b2.NeuronGroup(
    len(current), model=eqs, reset="v=v_reset", threshold="v>firing_threshold",
    refractory=refractory_time, method="euler")

neuron.v = v_rest  # set initial value
neuron.current = current*b2.pA

# monitoring membrane potential of neuron and injecting current
state_monitor = b2.StateMonitor(neuron, ["v"], record=True)
spike_monitor = b2.SpikeMonitor(neuron)
# run the simulation
b2.run(simulation_time*b2.second)

plt.figure(1)
plt.plot(neuron.current /b2.pA, spike_monitor.count/simulation_time, label = 'Fixacao forcada da voltagem')

plt.figure(2)
plt.plot(neuron.current/b2.pA, neuron.v/b2.mV, label = 'Fixacao forcada da voltagem')

plt.figure(3)
plt.plot(spike_monitor.count/simulation_time, neuron.v/b2.mV, label = 'Fixacao forcada da voltagem')

# Method threshold increase
eqs = """
dv/dt =
( ( (v_rest-v)/(membrane_capacitance * membrane_resistance) ) + (current/membrane_capacitance) ) : volt 
dVth/dt = (firing_threshold - Vth)/tau_refractory :  volt
current : amp
"""

# LIF neuron using Brian2 library
neuron = b2.NeuronGroup(
    len(current), model=eqs, reset="v=v_reset; Vth=Vth_reset", threshold="v>Vth",
    refractory=False, method="euler")
neuron.v = v_rest  # set initial value
neuron.Vth = firing_threshold
neuron.current = current*b2.pA

# monitoring membrane potential of neuron and injecting current
state_monitor = b2.StateMonitor(neuron, ["v", "Vth"], record=True)
spike_monitor = b2.SpikeMonitor(neuron)
# run the simulation
b2.run(simulation_time*b2.second)

plt.figure(1)
plt.plot(neuron.current/b2.pA, spike_monitor.count/simulation_time, label = 'Aumento do limiar')

plt.figure(2)
plt.plot(neuron.current/b2.pA, neuron.v/b2.mV, label = 'Aumento do limiar')

plt.figure(3)
plt.plot(spike_monitor.count/simulation_time, neuron.v/b2.mV, label = 'Aumento do limiar')

# Method refractory conductance
eqs = """
dGref/dt = -Gref/tau_Gref : siemens
dv/dt =
( ( (v_rest-v)/(membrane_capacitance * membrane_resistance) ) + (Gref *(E_k - v))/membrane_capacitance + (current/membrane_capacitance) ) : volt
dVth/dt = (firing_threshold - Vth)/tau_refractory :  volt
current : amp
"""
# LIF neuron using Brian2 library
neuron = b2.NeuronGroup(
    len(current), model=eqs, reset="Vth=Vth_reset; Gref=Gref+deltaG", threshold="v>Vth",
    refractory=False, method="euler")
neuron.v = v_rest  # set initial value
neuron.Vth = firing_threshold
neuron.Gref = Gref_0
neuron.current = current*b2.pA

# monitoring membrane potential of neuron and injecting current
state_monitor = b2.StateMonitor(neuron, ["v", "Vth", "Gref"], record=True)
spike_monitor = b2.SpikeMonitor(neuron)
# run the simulation
b2.run(simulation_time*b2.second)

plt.figure(1)
plt.plot(neuron.current/b2.pA, spike_monitor.count/simulation_time, label = 'Condutancia refrataria')
plt.xlabel('I (nA)')
plt.ylabel('Firing rate (sp/s)')
plt.grid()
plt.legend()
plt.title('Grafico da taxa de disparo em funcao da corrente')

plt.figure(2)
plt.plot(neuron.current/b2.pA, neuron.v/b2.mV, label = 'Condutancia refrataria')
plt.xlabel('I (nA)')
plt.ylabel('Voltage (mV)')
plt.grid()
plt.legend()
plt.title('Grafico da voltagem em funcao da corrente')

plt.figure(3)
plt.plot(spike_monitor.count/simulation_time, neuron.v/b2.mV, label = 'Condutancia refrataria')
plt.xlabel('Firing rate (sp/s)')
plt.ylabel('Voltage (mV)')
plt.grid()
plt.legend()
plt.title('Grafico da voltagem em funcao da taxa de disparo')

plt.show()
print(
      'As curvas com periodo refratario apresentam menor taxa de disparo quando comparadas '
      'com a sem periodo refratario. Pois, durante o periodo refratario não é possível gerar outro potencial de ação.'
      'Ocorrendo assim uma especie de "tempo morto" entre os disparos, diminuindo a quantidade de disparos. '
      'A fixacao forcada da voltagem obriga o potencial a ficar constante no limiar de -65mV no periodo refratario, '
      'consequentemente a curva de voltagem em funçao da corrente ou da taxa de disparo tende a -65mV, '
      'diferente da curva nao refrataria que tende a "fugir" desse limiar. No caso do aumento do limiar, '
      'a taxa de disparo é a mais próxima do metodo sem periodo refratario, apenas para correntes maiores as curvas '
      'comecam a divergir. Isso é devido ao fato que quanto maior o potencial  de entrada mais rápido o potencial '
      'de membrana ira atingir o limiar de decaimento. Para a condutancia refrataria com aumento do limiar '
      'ocorre uma associação entre os dois metodos anteriores resultando na menor taxa de disparo por corrente.'
      'A curva de voltagem por corrente apresenta a maior flutação, devido ao potencial do potassio de -80mV '
      'tende a ocorrer um plato nesse valor.'
    )
# Out:
# As curvas com periodo refratario apresentam menor taxa de disparo quando comparadas com a sem periodo refratario. Pois, durante o periodo refratario não é possível gerar outro potencial de ação.Ocorrendo assim uma especie de "tempo morto" entre os disparos, diminuindo a quantidade de disparos. A fixacao forcada da voltagem obriga o potencial a ficar constante no limiar de -65mV no periodo refratario, consequentemente a curva de voltagem em funçao da corrente ou da taxa de disparo tende a -65mV, diferente da curva nao refrataria que tende a "fugir" desse limiar. No caso do aumento do limiar, a taxa de disparo é a mais próxima do metodo sem periodo refratario, apenas para correntes maiores as curvas comecam a divergir. Isso é devido ao fato que quanto maior o potencial  de entrada mais rápido o potencial de membrana ira atingir o limiar de decaimento. Para a condutancia refrataria com aumento do limiar ocorre uma associação entre os dois metodos anteriores resultando na menor taxa de disparo por corrente.A curva de voltagem por corrente apresenta a maior flutação, devido ao potencial do potassio de -80mV tende a ocorrer um plato nesse valor.
